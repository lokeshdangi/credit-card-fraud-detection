# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv('creditcard.csv')

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
#data = data.sample(frac=0.1)
#data.shape

# %%
data.hist(figsize=(20,20))
plt.show()

# %%
n_valid = len(data[data['Class'] == 0])
n_fraud = len(data[data['Class'] == 1])
valid_percentage = n_valid/data.shape[0] 
fraud_percentage = n_fraud/data.shape[0]
print('Valid Cases: {}'.format(n_valid))
print('Fraud Cases: {}'.format(n_fraud))
print('Valid Percentage: {}'.format(valid_percentage * 100))
print('Fraud Percentage: {}'.format(fraud_percentage * 100))
# Out:
# Valid Cases: 284315
# Fraud Cases: 492
# Valid Percentage: 99.82725143693798
# Fraud Percentage: 0.1727485630620034

# %%
corr_mat = data.corr()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_mat)
plt.show()

# %%
features = data.columns.tolist()
features.remove('Class')
print(features)
# Out:
# ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']

# %%
target = 'Class'

# %%
X = data[features]
Y = data[target]

print(X.shape)
print(Y.shape)
# Out:
# (284807, 30)
# (284807,)

# %%
from sklearn.metrics import classification_report,accuracy_score
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import unsupervised

# %%
classifier = {
    'Isolation Forest': IsolationForest(max_samples=len(X),
                                        contamination = fraud_percentage)
}

# %%
for i,(clf_name,clf) in enumerate(classifier.items()):
    if clf_name =='Isolation Forest':
        clf.fit(X)
        pred_scores = clf.decision_function(X)
        y_pred = clf.predict(X)
        
    y_pred[y_pred == 1] = 0
    y_pred[y_pred == -1] = 1
    
    n_errors = (y_pred != Y).sum()
    
    print('{}:{}'.format(clf_name,n_errors))
    print('Accuracy Score: {}'.format(accuracy_score(Y,y_pred)))
    print(classification_report(Y,y_pred))
# Out:
# Isolation Forest:644
# Accuracy Score: 0.9977388196217087
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00    284315
#           1       0.35      0.35      0.35       492
#
# avg / total       1.00      1.00      1.00    284807
